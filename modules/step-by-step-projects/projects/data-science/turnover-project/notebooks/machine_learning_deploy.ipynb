# %% [markdown]
# # Pré-Processamento
# Comum antes de aplicarmos *Machine Learning* em nosso conjunto de dados fazermos um Pré-Processamento para deixar os dados prontinhos para trabalharmos.

# %% [markdown]
# ## 01 - Importando as bibliotenas necesárias
#
# Mas antes de iniciar com a aplicação de *Machine Learning* vamos importar as bibliotecas necessárias:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import glob

from minio import Minio

# %% [markdown]
# ## 02 - Conectando ao Data Lake com o MinIO
# Ok, como nós sabemos o **MinIO** é o orquestrador da nossa aplicação. Sabendo disso, nós vamos criar uma `instância` do **MinIO** que vai representar nossa conexão com ***Data Lake***:

# %%
client = Minio(
  "localhost:9000",
  access_key="minioadmin",
  secret_key="minioadmin",
  secure=False
)

# %% [markdown]
# ## 03 - Baixando o Dataset do Data Lake
# Agora que nós já criamos uma conexão *(Representação abstrata)* para o nosso ***Data Lake*** com **MinIO** vamos baixar os dados de lá *(Lembrando que nós salvamos esses dados no formato .parquet)*:

# %%
client.fget_object(
  "processing", # Landing - Diretório (Bucket) que estamos buscando.
  "employees_dataset.parquet", # Nome do arquivo que vamos baixar.
  "temp_.parquet", # Nome do arquivo temporário para armazenar o que vamos baixar.
)

df = pd.read_parquet("temp_.parquet")

# %% [markdown]
# Agora com o nosso conjunto de dados baixados vamos dar uma visualizada apenas nas primeiras amostras:

# %%
df.head(10)
# Out:
#   department  salary  left  mean_work_last_3_months  number_projects  \
# 0      sales     low   1.0               266.000000              2.0
# 1      sales  medium   1.0               252.000000              5.0
# 2      sales  medium   1.0               289.666667              7.0
# 3      sales     low   1.0               275.666667              5.0
# 4      sales     low   1.0               292.333333              2.0
# 5      sales     low   1.0               271.000000              2.0
# 6      sales     low   1.0               268.666667              6.0
# 7      sales     low   1.0               274.666667              5.0
# 8      sales     low   1.0               269.333333              5.0
# 9      sales     low   1.0               280.000000              2.0
#
#    satisfaction_level  last_evaluation  time_in_company  work_accident
# 0                38.0             53.0              3.0            0.0
# 1                80.0             86.0              6.0            0.0
# 2                11.0             88.0              4.0            0.0
# 3                72.0             87.0              5.0            0.0
# 4                37.0             52.0              3.0            0.0
# 5                41.0             50.0              3.0            0.0
# 6                10.0             77.0              4.0            0.0
# 7                92.0             85.0              5.0            0.0
# 8                89.0            100.0              5.0            0.0
# 9                42.0             53.0              3.0            0.0

# %% [markdown]
# ## 04 - Organizando o Dataset (Colunas ou Features)
# Ok, agora com os dados baixados vamos organizar algumas coisas para ficar mais fácil de trabalhar. A primeira coisa que vamos fazer aqui será ordenar as colunas:

# %%
df = df[
  [
    'department',
    'salary',
    'mean_work_last_3_months',
    'number_projects',
    'satisfaction_level',
    'last_evaluation',
    'time_in_company',
    'work_accident',
    'left'
  ]
]

# %% [markdown]
# Agora com as colunas ordenadas da maneira que nós desejamos, vamos  agora visualizar para ver como ficou:

# %%
df.head()
# Out:
#   department  salary  mean_work_last_3_months  number_projects  \
# 0      sales     low               266.000000              2.0
# 1      sales  medium               252.000000              5.0
# 2      sales  medium               289.666667              7.0
# 3      sales     low               275.666667              5.0
# 4      sales     low               292.333333              2.0
#
#    satisfaction_level  last_evaluation  time_in_company  work_accident  left
# 0                38.0             53.0              3.0            0.0   1.0
# 1                80.0             86.0              6.0            0.0   1.0
# 2                11.0             88.0              4.0            0.0   1.0
# 3                72.0             87.0              5.0            0.0   1.0
# 4                37.0             52.0              3.0            0.0   1.0

# %% [markdown]
# ## 05 - Verificando os registros missing
# Bem, agora nós vamos iniciar a faze de Pré-Processamento dos dados. De início vamos ver se temos registros nulos:

# %%
df.isnull().sum()
# Out:
# department                 1
# salary                     1
# mean_work_last_3_months    0
# number_projects            1
# satisfaction_level         1
# last_evaluation            1
# time_in_company            1
# work_accident              1
# left                       1
# dtype: int64

# %% [markdown]
# **NOTE:**
# Veja que nós só temos um registro nulo.
#
# Uma maneira inteligente de ver qual é esse registro (ou amostra) é utilizar a função **notnull()** do Pandas que exibe apenas os registros (amostras) `não nulas`:

# %%
df[df.notnull()]
# Out:
#       department  salary  mean_work_last_3_months  number_projects  \
# 0          sales     low               266.000000              2.0
# 1          sales  medium               252.000000              5.0
# 2          sales  medium               289.666667              7.0
# 3          sales     low               275.666667              5.0
# 4          sales     low               292.333333              2.0
# ...          ...     ...                      ...              ...
# 14995    support     low               253.333333              2.0
# 14996    support     low               288.000000              2.0
# 14997    support     low               272.000000              6.0
# 14998    support     low               276.666667              2.0
# 14999        NaN     NaN               261.000000              NaN
#
#        satisfaction_level  last_evaluation  time_in_company  work_accident  \
# 0                    38.0             53.0              3.0            0.0
# 1                    80.0             86.0              6.0            0.0
# 2                    11.0             88.0              4.0            0.0
# 3                    72.0             87.0              5.0            0.0
# 4                    37.0             52.0              3.0            0.0
# ...                   ...              ...              ...            ...
# 14995                37.0             48.0              3.0            0.0
# 14996                37.0             53.0              3.0            0.0
# 14997                11.0             96.0              4.0            0.0
# 14998                37.0             52.0              3.0            0.0
# 14999                 NaN              NaN              NaN            NaN
#
#        left
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# ...     ...
# 14995   1.0
# 14996   1.0
# 14997   1.0
# 14998   1.0
# 14999   NaN
#
# [15000 rows x 9 columns]

# %% [markdown]
# **NOTE:**
# Veja que apenas o último registro está com dados faltantes. E mesmo assim ele ainda tem dados referentes a média de horas trabalhadas. Então, cabe a você pensar se esse dado é crucial ou não para a análise.
#
# Para nosso exemplo, vamos apenas excluir essa amostra, já que só tem ela:

# %%
df = df[:14998]

# %% [markdown]
# ## 06 - Alterando os tipos de dados
# Agora nós vamos ver qual o tipo de dado em cada coluna (feature) do nosso Dataset. Para isso vamos primeiro utilizar o atributo **dtypes** do Pandas para fazer essa verificação:

# %%
df.dtypes
# Out:
# department                  object
# salary                      object
# mean_work_last_3_months    float64
# number_projects            float64
# satisfaction_level         float64
# last_evaluation            float64
# time_in_company            float64
# work_accident              float64
# left                       float64
# dtype: object

# %% [markdown]
# Talvez os dados já estejam da maneira que nós precisamos, mas vou aplicar um Pré-Processamento bem básico só para vocês aprenderem como funciona na prática essa alteração de tipos de dados:

# %%
df["number_projects"] = df["number_projects"].astype(int)
df["mean_work_last_3_months"] = df["mean_work_last_3_months"].astype(int)
df["time_in_company"] = df["time_in_company"].astype(int)
df["work_accident"] = df["work_accident"].astype(int)
df["left"] = df["left"].astype(int)

# %% [markdown]
# **NOTE:**
# Outra maneira de visualizar os tipos de dados e até ter uma visão mais global do nosso Dataset é utilizar a função **info()**.
#
# Vamos ver na prática como fica mais bonito:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14998 entries, 0 to 14997
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   department               14998 non-null  object
#  1   salary                   14998 non-null  object
#  2   mean_work_last_3_months  14998 non-null  int64
#  3   number_projects          14998 non-null  int64
#  4   satisfaction_level       14998 non-null  float64
#  5   last_evaluation          14998 non-null  float64
#  6   time_in_company          14998 non-null  int64
#  7   work_accident            14998 non-null  int64
#  8   left                     14998 non-null  int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 1.0+ MB

# %%
df.head()
# Out:
#   department  salary  mean_work_last_3_months  number_projects  \
# 0      sales     low                      266                2
# 1      sales  medium                      252                5
# 2      sales  medium                      289                7
# 3      sales     low                      275                5
# 4      sales     low                      292                2
#
#    satisfaction_level  last_evaluation  time_in_company  work_accident  left
# 0                38.0             53.0                3              0     1
# 1                80.0             86.0                6              0     1
# 2                11.0             88.0                4              0     1
# 3                72.0             87.0                5              0     1
# 4                37.0             52.0                3              0     1

# %% [markdown]
# ## 07 - Renomeando atributos (Features)
# Bem, agora nós vamos renomear esses atributos (features) para ficar mais parecido com o nosso problema. Ou seja, vamos dar nomes mais limpos:

# %%
df = df.rename(columns={
  'satisfaction_level': 'satisfaction',
  'last_evaluation': 'evaluation',
  'number_projects': 'projectCount',
  'mean_work_last_3_months': 'averageMonthlyHours',
  'time_in_company': 'yearsAtCompany',
  'work_accident': 'workAccident',
  'left' : 'turnover'
})

# %%
df.head()
# Out:
#   department  salary  averageMonthlyHours  projectCount  satisfaction  \
# 0      sales     low                  266             2          38.0
# 1      sales  medium                  252             5          80.0
# 2      sales  medium                  289             7          11.0
# 3      sales     low                  275             5          72.0
# 4      sales     low                  292             2          37.0
#
#    evaluation  yearsAtCompany  workAccident  turnover
# 0        53.0               3             0         1
# 1        86.0               6             0         1
# 2        88.0               4             0         1
# 3        87.0               5             0         1
# 4        52.0               3             0         1

# %% [markdown]
# # Machine Learning
#
# > **Agora sim nós vamos colocar em prática um pouco de *Machine Learning*.**

# %% [markdown]
# ## 08 - Convertendo atributos em categorias
# Ok, agora que nós vamos iniciar de fato a aplicação de Algoritmos de *Machine Learning* em nosso conjunto de dados, vale salientar que nós conhecemos os atributos (variáveis) do nosso dataset como **Features**.
#
# Agora vem a questão crucial que é:
#
# > Quais **Features** são realmente importantes (cruciais) para os meus Algoritmos tentarem fazer alguma `predição (predict)`?
#
# **NOTE:**
# Bem, por agora vamos focar no seguinte. A maioria dos Algoritmos de *Machine Learning* trabalham com nossas **Features** como se fossem dados numéricos. Mas se você olhar bem as **Features** *departament* e *salary* não estão no formato numérico.
#
# Veja abaixo:

# %%
df.dtypes
# Out:
# department              object
# salary                  object
# averageMonthlyHours      int64
# projectCount             int64
# satisfaction           float64
# evaluation             float64
# yearsAtCompany           int64
# workAccident             int64
# turnover                 int64
# dtype: object

# %% [markdown]
# **NOTE:**
# Veja que ambas **Features** são do tipo object. Uma alternativa (é só uma alternativa, não que dizer que sempre você deve utilizar essa approach) é categorizar essas **Features**.
#
# Para fazer isso é muito simples, com Pandas:

# %%
df['department'] = df['department'].astype('category').cat.codes
df['salary'] = df['salary'].astype('category').cat.codes

# %%
df.dtypes
# Out:
# department                int8
# salary                    int8
# averageMonthlyHours      int64
# projectCount             int64
# satisfaction           float64
# evaluation             float64
# yearsAtCompany           int64
# workAccident             int64
# turnover                 int64
# dtype: object

# %% [markdown]
# Veja que agora as **Features** estão do tipo *int*. Vamos visualizar isso para ver como fica na prática:

# %%
df.head(50)
# Out:
#     department  salary  averageMonthlyHours  projectCount  satisfaction  \
# 0            7       1                  266             2          38.0
# 1            7       2                  252             5          80.0
# 2            7       2                  289             7          11.0
# 3            7       1                  275             5          72.0
# 4            7       1                  292             2          37.0
# 5            7       1                  271             2          41.0
# 6            7       1                  268             6          10.0
# 7            7       1                  274             5          92.0
# 8            7       1                  269             5          89.0
# 9            7       1                  280             2          42.0
# 10           7       1                  274             2          45.0
# 11           7       1                  280             6          11.0
# 12           7       1                  279             4          84.0
# 13           7       1                  286             2          41.0
# 14           7       1                  270             2          36.0
# 15           7       1                  291             2          38.0
# 16           7       1                  258             2          45.0
# 17           7       1                  287             4          78.0
# 18           7       1                  277             2          45.0
# 19           7       1                  290             5          76.0
# 20           7       1                  270             6          11.0
# 21           7       1                  265             2          38.0
# 22           7       1                  262             6           9.0
# 23           7       1                  265             2          46.0
# 24           7       1                  275             2          40.0
# 25           7       1                  274             5          89.0
# 26           7       1                  276             4          82.0
# 27           7       1                  278             2          40.0
# 28           2       1                  283             2          41.0
# 29           2       1                  281             2          38.0
# 30           2       1                  259             6           9.0
# 31           3       1                  284             2          45.0
# 32           3       1                  289             2          40.0
# 33           3       1                  280             2          45.0
# 34           3       1                  261             4          84.0
# 35           9       1                  299             6          10.0
# 36           9       1                  276             2          38.0
# 37           9       1                  270             2          45.0
# 38           9       1                  279             6          11.0
# 39           9       1                  273             2          41.0
# 40           9       1                  288             5          87.0
# 41           9       1                  277             2          45.0
# 42           9       1                  269             2          40.0
# 43           9       1                  264             7          10.0
# 44           9       1                  282             6           9.0
# 45           9       1                  265             3          84.0
# 46           8       1                  294             2          40.0
# 47           8       1                  281             3          57.0
# 48           8       1                  286             2          40.0
# 49           8       1                  252             2          43.0
#
#     evaluation  yearsAtCompany  workAccident  turnover
# 0         53.0               3             0         1
# 1         86.0               6             0         1
# 2         88.0               4             0         1
# 3         87.0               5             0         1
# 4         52.0               3             0         1
# 5         50.0               3             0         1
# 6         77.0               4             0         1
# 7         85.0               5             0         1
# 8        100.0               5             0         1
# 9         53.0               3             0         1
# 10        54.0               3             0         1
# 11        81.0               4             0         1
# 12        92.0               5             0         1
# 13        55.0               3             0         1
# 14        56.0               3             0         1
# 15        54.0               3             0         1
# 16        47.0               3             0         1
# 17        99.0               6             0         1
# 18        51.0               3             1         1
# 19        89.0               5             0         1
# 20        83.0               4             0         1
# 21        55.0               3             0         1
# 22        95.0               4             0         1
# 23        57.0               3             0         1
# 24        53.0               3             0         1
# 25        92.0               5             0         1
# 26        87.0               5             0         1
# 27        49.0               3             0         1
# 28        46.0               3             0         1
# 29        50.0               3             0         1
# 30        62.0               4             0         1
# 31        57.0               3             0         1
# 32        51.0               3             0         1
# 33        55.0               3             0         1
# 34        87.0               6             0         1
# 35        94.0               4             0         1
# 36        46.0               3             0         1
# 37        50.0               3             0         1
# 38        89.0               4             0         1
# 39        54.0               3             0         1
# 40        88.0               5             0         1
# 41        48.0               3             0         1
# 42        46.0               3             0         1
# 43        80.0               4             0         1
# 44        89.0               4             0         1
# 45        74.0               4             0         1
# 46        55.0               3             0         1
# 47        70.0               6             0         1
# 48        54.0               3             0         1
# 49        47.0               3             0         1

# %% [markdown]
# **NOTE:**
# Mas o que muda essa approach de apenas nós mudarmos nós mesmos para o tipo *int*?
#
# **NOTE:**
# Bem, o que acontece é que por baixo dos panos nós classificamos (categorizamos) cada departamento e cada tipo de salário por valores numéricos.
#
# Não entendeu? Veja os códigos abaixo para ficar mais claro:

# %%
departament_rate = df.department.value_counts()
departament_rate
# Out:
# 7    4140
# 9    2720
# 8    2228
# 0    1227
# 6     902
# 5     858
# 1     787
# 2     767
# 3     739
# 4     630
# Name: department, dtype: int64

# %%
salary_rate = df.salary.value_counts()
salary_rate
# Out:
# 1    7315
# 2    6446
# 0    1237
# Name: salary, dtype: int64

# %% [markdown]
# Veja que:
#  - Antes nós tinhamos 10 tipos de departamentos e agora nós temos uma classificação de departamentos de 0 e 9 (ou seja 10);
#  - E tinhamos 3 tipos de salários (Low, Medium e Hight) e agora temos uma classificação de 0 a 2 (ou seja 3).
#
# **NOTE:**
# Na verdade **talvez** essa seja uma das maneiras mais inteligentes de se trabalhar com dados não numéricos. Classificamos eles para só depois relacionarmos eles com outras **Features**.

# %% [markdown]
# ## 09 - Separando os conjuntos de dados
# Bem, como nós sabemos é comum em Machine Learning nós termos as variáveis:
#
#  - Variáveis *independentes*, entradas ou preditoras;
#  - Variáveis *dependentes*, saídas ou respostas.
#
# Agora nós vamos separar essas *variáveis (features)* para só depois aplicarmos em um Algoritmo de *Machine Learning*:

# %%
target_name = 'turnover'
x = df.drop('turnover', axis=1)
y = df[target_name]

# %% [markdown]
# Vamos agora visualizar isso:

# %%
x
# Out:
#        department  salary  averageMonthlyHours  projectCount  satisfaction  \
# 0               7       1                  266             2          38.0
# 1               7       2                  252             5          80.0
# 2               7       2                  289             7          11.0
# 3               7       1                  275             5          72.0
# 4               7       1                  292             2          37.0
# ...           ...     ...                  ...           ...           ...
# 14993           9       1                  279             6          76.0
# 14994           8       1                  287             2          40.0
# 14995           8       1                  253             2          37.0
# 14996           8       1                  288             2          37.0
# 14997           8       1                  272             6          11.0
#
#        evaluation  yearsAtCompany  workAccident
# 0            53.0               3             0
# 1            86.0               6             0
# 2            88.0               4             0
# 3            87.0               5             0
# 4            52.0               3             0
# ...           ...             ...           ...
# 14993        83.0               6             0
# 14994        57.0               3             0
# 14995        48.0               3             0
# 14996        53.0               3             0
# 14997        96.0               4             0
#
# [14998 rows x 8 columns]

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14993    1
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# Name: turnover, Length: 14998, dtype: int64

# %% [markdown]
# ## 10 - Normalizando os dados
# Bem, como vocês já viram nossas **Features** (eixo x) estão em várias ordem de grandeza. Ou seja, é muito interessante nós trazermos todas as features para a mesma ordem de grandeza:

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() # Instance
x = scaler.fit_transform(x)
x
# Out:
# array([[0.77777778, 0.5       , 0.38202247, ..., 0.265625  , 0.125     ,
#         0.        ],
#        [0.77777778, 1.        , 0.2247191 , ..., 0.78125   , 0.5       ,
#         0.        ],
#        [0.77777778, 1.        , 0.64044944, ..., 0.8125    , 0.25      ,
#         0.        ],
#        ...,
#        [0.88888889, 0.5       , 0.23595506, ..., 0.1875    , 0.125     ,
#         0.        ],
#        [0.88888889, 0.5       , 0.62921348, ..., 0.265625  , 0.125     ,
#         0.        ],
#        [0.88888889, 0.5       , 0.4494382 , ..., 0.9375    , 0.25      ,
#         0.        ]])

# %% [markdown]
# **NOTE:**
# Veja que agora os dados das nossas *features* estão na mesma ordem de grandeza.

# %% [markdown]
# ## 11 - Separando os dados em dados de treino e dados de teste
# Ok, agora que nós já normalizamos nossos dados vamos separar eles entre **dados de treino** e **dados de teste**:

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
  x,
  y,
  test_size = 0.2,
  random_state = 123,
  stratify = y
)

# %% [markdown]
# **NOTE:**
# Bem, como vocês sabem a nossa variável **target (turnover)** está muito desbalanceada *(76% para funcionarários que permanerem e 23% dos que deixaram a empresa)*, por isso, vamos aplicar em conjunto com essa separação dos dados em treino e teste o Algoritmo **Stratified K-Fold**.
#
# Isso foi feito quando utilizamos o argumento - **stratify = y**

# %% [markdown]
# ## 12 - Treinando nosso modelo com o Algoritmo Decision Tree
# Um Algoritmo muito utilizado em *Machine Learning* é o **Decision Tree**... Vamos começar utilizando ele para ver como nosso conjunto de dados de comporta:

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier() # Instance.
dtree = dtree.fit(x_train, y_train) # Model Training.

# %% [markdown]
# ## 13 - Selecionando as melhores features para o nosso modelo
# Bem, acima nós praticamente já treinamos o nosso modelo, mas como eu posso saber quais **Features** foram mais relevantes, ou seja, quais são mais importantes?
#
# > Uma approach é utilizar o atributo **feature_importances_** do Algoritmo **Devision Tree**.
#
# Veja como aplicar isso abaixo:

# %%
features_percents = dtree.feature_importances_
features_percents
# Out:
# array([0.07615708, 0.02620032, 0.20495806, 0.07123287, 0.30654217,
#        0.20708186, 0.09271243, 0.0151152 ])

# %% [markdown]
# **NOTE:**
# O atributo **feature_importances_** nós retorna quanto *porcento (%)* cada feature (coluna, variável, atributo) contribuiu para o treinamento do nosso modelo.

# %% [markdown]
# ## 14 - Criando um gráfico para representar as melhores features
# Agora vamos criar uma gráfico que vai demonstrar de forma visual quais features foram mais relevantes para o treinamento do nosso modelo:
#
# **NOTE:**
# Mas antes vamos salvar os nomes de todas as features em uma variável - **features_names**:

# %%
features_names = df.drop(['turnover'], axis=1).columns
features_names
# Out:
# Index(['department', 'salary', 'averageMonthlyHours', 'projectCount',
#        'satisfaction', 'evaluation', 'yearsAtCompany', 'workAccident'],
#       dtype='object')

# %% [markdown]
# Pronto, agora que já temos os nomes de todas nossas *features (variáveis, atributos, colunas)* salvas vamos criar nosso gráfico:

# %%
indices = np.argsort(features_percents)[::-1]

# Plot settings
plt.figure(figsize=(12, 4))
plt.title("Feature importances by DecisionTreeClassifier")
plt.bar(
  range(len(indices)),
  features_percents[indices],
  color='lightblue',
  align="center"
)

plt.xticks(
  range(len(indices)),
  features_names[indices],
  rotation='vertical',
  fontsize=14)
plt.xlim([-1, len(indices)])

plt.show()

# %% [markdown]
# ## 15 - Filtrando apenas as Features mais relevantes
# Bem, agora que nós já sabemos quais *Features* são mais relevantes, vamos aplicar um tipo de filtro para o nosso modelo aprender, porém, apenas com as *Features* mais importantes.
#
# Primeiro, vamos passar para a nossa variável **"x"** apenas as *Features* mais relevantes:

# %%
x = df[
  [
    "satisfaction",
    "evaluation",
    "averageMonthlyHours",
    "yearsAtCompany"
  ]
]

# %% [markdown]
# Agora  nós vamos novamente:
#  - Normalizar os dados;
#  - E separar em dados de treino e dados de teste.
#
# **NOTE:**
# Por que fazer esse processo novamente? Porque quando nós utilizamos `df[x, y,z]` nós trouxemos os dados originais do dataset, ou seja, sem normalização e separação.

# %%
# Data normalization.
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# Data splitting.
x_train, x_test, y_train, y_test = train_test_split(
  x,
  y,
  test_size = 0.2,
  random_state = 123,
  stratify = y
)

# %% [markdown]
# ## 16 - Definindo uma função para representar um "Modelo de Baseline"
# Para entender como funciona um **modelo de baseline**, vamos seguir com a seguinte analogia:
#
# Se eu jogar uma moeda **"n"** vezes (um processo aleatório), onde:
#
#  - **Cara** vai representar as pessoas que permaneceram na empresa (0 no nosso dataset);
#  - **Coroa** vai representar as pessoas que deixaram a empresa (1 no nosso dataset).
#
# Agora vem a pergunta chave:
#
# > **Será que o meu modelo vai ganhar ou predizer melhor do que essas jogadas aleatórias?
#
# **NOTE:**
# Imagine que nós criamos um recurso aleatório (por exemplo, um programa) que entregue 0 ou 1 para representar pessoas que permanecem e saíram da empresa - **Se o nosso modelo for *menos inteligente* que isso não valeu de nada nosso trabalho**.
#
# **NOTE:**
# Essa analogia que nós seguimos acima é apenas um exemplo. O importante aqui a se saber é que nosso **modelo de baseline** é algo que nós vamos bater (ou ganhar) quando comparado com nossos Algoritmos de Machine Learning, senão, nosso modelo de Machine Learning é ineficiente se comparado com ele **(modelo de baseline)**.
#
# ---
#
# Outro exemplo (analogia) aqui seria a seguinte. Suponha, que nós vamos tentar estimar quantas vendas nós vamos ter por dia. Agora imagine que o meu **modelo de baseline** segue a seguinte lógica para fazer essa estimativa:
#
# > O meu **modelo de baseline** tira a média de todas as vendas por dia e faz uma estimativa baseada nessa média.
#
# **NOTE:**
# Ou seja, para o meu Algoritmo de *Machine Learning* predizer ou ganhar do meu **modelo de baseline** ele vai ter que ser melhor do que apenas tirar a média de todas as vendas por dia. O que faz todo sentido, porque se o meu Algoritmo for menos eficiente do que tirar a média (que é uma estatística muita básica) talvez não vala a pena seguir a lógica do Algoritmo implementado.
#
# **NOTE:**
# Por fim, vale salientar que o nosso **modelo de baseline** pode ser uma ***referência*** quando formos apresentar nossa solução. Por exemplo:
#
#  - O meu Algoritmo **"x"** é melhor **"n" porcento (%)** se comparado com a média (de vendas por exemplo);
#  - O meu Algoritmo **"x"** é melhor **"n" porcento (%)** se comparado com um recurso aleatório...
#
# Veja o código abaixo para ver um exemplo (muito simples) de **modelo de baseline**:

# %%
def baseline_model(x):
  y = np.zeros(x.shape[0])
  return y

# %% [markdown]
# **NOTE:**
# O que o nosso **modelo de baseline** acima fez foi o seguinte:
#
# > Pegou um conjunto de dados **"x"** e retornou **0** para todos os elementos.

# %% [markdown]
# ## 17 - Importando métodos de métrica de avaliação
# Agora nós vamos importar os métodos do Scikit-Learn que nós vamos utilizar para fazer uma avaliação de métrica sobre nosso modelo:

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# Agora nós vamos criar uma função que retorna a **accuracy** do nosso modelo, ou seja, quanto porcento (%) nosso modelo acertou? Essa função vai receber:
#  - Os dados y de teste;
#  - O que o nosso modelo ou modelo de baseline preveu.
#  - Por fim, retorna accuracy do nosso modelo. Ou seja, quanto porcento (%) nosso modelo ou modelo de baseline acertou.

# %%
def accuracy_result(y_test, y_predicted_model_or_baseline):
  accuracy = accuracy_score(y_test, y_predicted_model_or_baseline)
  print ("Accuracy = %2.2f" % accuracy)

# %% [markdown]
# Agora vamos criar uma função que nós retorna a curva ROC e outras análises interessantes:

# %%
def roc_classification_report_results(model, y_test, y_predicted_model_or_baseline):
  roc_ = roc_auc_score(y_test, y_predicted_model_or_baseline)
  classfication_report = classification_report(y_test, y_predicted_model_or_baseline)
    
  print ("\n{} AUC = {}\n".format(model, roc_))
  print(classfication_report)

# %% [markdown]
# ## 18 - Testando nosso modelo de baseline
# Bem, agora chegou a hora de testar nosso **modelo de baseline**. Para esse exemplo o que nós vamos fazer é passar os **dados "x" de teste** para o nosso *modelo de baseline* (que nós sabemos que vai retornar 0 para todos os elementos):

# %%
y_predicted_baseline = baseline_model(x_test)

# %% [markdown]
# **NOTE:**
# Bem, agora nós vamos chamar a função **accuracy_result()** que recebe como argumento:
#  - Os y de teste;
#  - E o resultado do nosso modelo de baseline (y_predicted_baseline);
#  - Por fim, retorna qual a accuracy do nosso d

# %%
accuracy_result(y_test, y_predicted_baseline)
# Out:
# Accuracy = 0.76

# %% [markdown]
# **NOTE:**
# Veja que o nosso **modelo de baseline** teve um acerto de 76%.

# %%
roc_classification_report_results("Base Model", y_test, y_predicted_baseline)
# Out:
# Base Model AUC = 0.5
#
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86      2286
#            1       0.00      0.00      0.00       714
#
#     accuracy                           0.76      3000
#    macro avg       0.38      0.50      0.43      3000
# weighted avg       0.58      0.76      0.66      3000
# /home/drigols/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **NOTE:**
# Veja que nós não acertamos nenhuma na classe 1, isso porque os dados que nós tivemos como retorno da função **baseline_model()** foram todos 0 como nós definimos.
#
# **NOTE:**
# Outras 2 observações aqui são as seguintes:
#  - Primeiro, que a **accuracy** do **modelo de baseline** não reflete bem sobre a realidade do nosso problema.
#  - Segundo, os dados estão muito desbalanceados, tanto, que até o Scikit-Learn nós retornou um **warning** sobre isso.

# %% [markdown]
# ## 19 - Treinando nosso modelo com o Algoritmo de Regressão Logística
# Ok, agora nós vamos treinar nosso modelo novamente, porém, utlizando o Algoritmo de **Regressão Logística**:

# %%
from sklearn.linear_model import LogisticRegression
logis = LogisticRegression()

logis.fit(x_train, y_train)
y_predict = logis.predict(x_test)

# %% [markdown]
# **NOTE:**
# Agora que nós já treinamos nosso modelo vamos verificar qual foi a **accuracy** do nosso modelo, ou seja, quanto porcento (%) ele acertou:

# %%
accuracy_result(y_test, y_predict)
# Out:
# Accuracy = 0.75

# %%
roc_classification_report_results("Logistic Regression", y_test, y_predict)
# Out:
# Logistic Regression AUC = 0.49978495335141926
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.99      0.86      2286
#            1       0.23      0.01      0.03       714
#
#     accuracy                           0.75      3000
#    macro avg       0.50      0.50      0.44      3000
# weighted avg       0.64      0.75      0.66      3000

# %% [markdown]
# ## 20 - Treinando nosso modelo com o Algoritmo de Arvore de decisão (de novo)
#
# > Será que com um Algoritmo de Machine Learning diferente nós conseguimos uma **accuracy** melhor?
#
# Então, só existe uma maneira de saber a resposta acima - **TESTANDO!**
#
# ---
#
# Sabendo disso agora nós vamos testar o Algoritmo de Árvore de Decisão (Decision Tree):

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier() # Instance.
dtree = dtree.fit(x_train, y_train) # Model training.
y_predict = dtree.predict(x_test) # Calculating predicts.

# %% [markdown]
# **NOTE:**
# Agora que nós já treinamos nosso modelo e calculamos precisões, vamos ver como ficou a **accuracy**:

# %%
accuracy_result(y_test, y_predict)
# Out:
# Accuracy = 0.73

# %%
roc_classification_report_results("Decision Tree", y_test, y_predict)
# Out:
# Decision Tree AUC = 0.6393612563135491
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      2286
#            1       0.44      0.47      0.45       714
#
#     accuracy                           0.73      3000
#    macro avg       0.63      0.64      0.64      3000
# weighted avg       0.74      0.73      0.73      3000

# %% [markdown]
# **NOTE:**
# Veja que nós tivemos uma **accuracy** menor, porém, nossa curva AUC foi melhor se comparada com outros Algoritmos.

# %% [markdown]
# ## 21 - Treinando nosso modelo com o Algoritmo de Arvore Aleatória (Random Forest)
# Por fim, vamos testar mais um Algoritmo que é o **Árvore Aleatória (Random Forest)**:

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier() # Instance.
rf = rf.fit(x_train, y_train) # Model training.
y_predict = rf.predict(x_test) # Calculating predicts.

# %% [markdown]
# **NOTE:**
# Agora que nós já treinamos nosso modelo e calculamos precisões, vamos ver como ficou a **accuracy**:

# %%
accuracy_result(y_test, y_predict)
# Out:
# Accuracy = 0.80

# %%
roc_classification_report_results("Random Forest", y_test, y_predict)
# Out:
# Random Forest AUC = 0.6867358491953213
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88      2286
#            1       0.62      0.46      0.53       714
#
#     accuracy                           0.80      3000
#    macro avg       0.73      0.69      0.70      3000
# weighted avg       0.79      0.80      0.79      3000

# %% [markdown]
# **NOTE:**
# Veja que esse Algoritmo foi o que deu a melhor **accuracy** e melhor **Curva AUC**.

# %% [markdown]
# ## 22 - Observação sobre "Accuracy" de um modelo
# Bem, aqui é só uma observação (análise) que é a seguinte:
#
# > Nós não devemos focar na **accuracy** do nosso modelo quando estivermos dados desbalanceados - Por exemplo, nosso turnover está muito desbalanceado.
#
# **NOTE:**
# Sabendo que não é interessante focar na **accuracy** quando nossos dados estiverem muito desbalanceados é interessante seguir outras approach - **Como Curva AUC**

# %% [markdown]
# ## 23 - Introdução ao Pycaret
#
# > **Pycaret** para quem não sabe é uma biblioteca para nós trabalharmos com **AutoML (Auto Machine Learning)**
#
# Quais as vantagens do Pycaret? - **Ser mais produtivo**
#  - Escrevendo menos códigos;
#  - Escolhendo Algoritmos pronto;
#  - Escolhendo pipelines;
#  - Escolhendo melhores métricas por Algoritmo;
#  - Testes de modelos;
#  - Comparação de modelos;
#  - Menos erro de codificação..
#
# Agora vamos instalar a biblioteca **pycaret**:

# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in /home/drigols/anaconda3/lib/python3.9/site-packages (2.3.5)
# Requirement already satisfied: Boruta in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (0.3)
# Requirement already satisfied: IPython in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (7.29.0)
# Requirement already satisfied: numpy==1.19.5 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (1.19.5)
# Requirement already satisfied: ipywidgets in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: cufflinks>=0.17.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (0.17.3)
# Requirement already satisfied: seaborn in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (0.11.2)
# Requirement already satisfied: pandas-profiling>=2.8.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (3.1.0)
# Requirement already satisfied: pandas in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (1.3.4)
# Requirement already satisfied: kmodes>=0.10.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (0.11.1)
# Requirement already satisfied: umap-learn in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (0.5.2)
# Requirement already satisfied: spacy<2.4.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (2.3.7)
# Requirement already satisfied: matplotlib in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (3.4.3)
# Requirement already satisfied: joblib in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (1.0.1)
# Requirement already satisfied: nltk in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (3.6.5)
# Requirement already satisfied: textblob in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (0.17.1)
# Requirement already satisfied: imbalanced-learn==0.7.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (0.7.0)
# Requirement already satisfied: pyLDAvis in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (3.2.2)
# Requirement already satisfied: scikit-learn==0.23.2 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (0.23.2)
# Requirement already satisfied: plotly>=4.4.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (5.5.0)
# Requirement already satisfied: mlxtend>=0.17.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (0.19.0)
# Requirement already satisfied: mlflow in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (1.22.0)
# Requirement already satisfied: pyod in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (0.9.6)
# Requirement already satisfied: yellowbrick>=1.0.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (1.3.post1)
# Requirement already satisfied: scipy<=1.5.4 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (1.5.4)
# Requirement already satisfied: gensim<4.0.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (3.8.3)
# Requirement already satisfied: scikit-plot in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: lightgbm>=2.3.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (3.3.1)
# Requirement already satisfied: wordcloud in /home/drigols/anaconda3/lib/python3.9/site-packages (from pycaret) (1.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from scikit-learn==0.23.2->pycaret) (2.2.0)
# Requirement already satisfied: colorlover>=0.2.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from cufflinks>=0.17.0->pycaret) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from cufflinks>=0.17.0->pycaret) (58.0.4)
# Requirement already satisfied: six>=1.9.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from cufflinks>=0.17.0->pycaret) (1.16.0)
# Requirement already satisfied: smart-open>=1.8.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from gensim<4.0.0->pycaret) (5.2.1)
# Requirement already satisfied: backcall in /home/drigols/anaconda3/lib/python3.9/site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: decorator in /home/drigols/anaconda3/lib/python3.9/site-packages (from IPython->pycaret) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from IPython->pycaret) (3.0.20)
# Requirement already satisfied: pygments in /home/drigols/anaconda3/lib/python3.9/site-packages (from IPython->pycaret) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in /home/drigols/anaconda3/lib/python3.9/site-packages (from IPython->pycaret) (0.18.0)
# Requirement already satisfied: traitlets>=4.2 in /home/drigols/anaconda3/lib/python3.9/site-packages (from IPython->pycaret) (5.1.0)
# Requirement already satisfied: matplotlib-inline in /home/drigols/anaconda3/lib/python3.9/site-packages (from IPython->pycaret) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /home/drigols/anaconda3/lib/python3.9/site-packages (from IPython->pycaret) (4.8.0)
# Requirement already satisfied: pickleshare in /home/drigols/anaconda3/lib/python3.9/site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from ipywidgets->pycaret) (6.4.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from ipywidgets->pycaret) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from ipywidgets->pycaret) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from ipywidgets->pycaret) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from ipywidgets->pycaret) (3.5.1)
# Requirement already satisfied: jupyter-client<8.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/drigols/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->IPython->pycaret) (0.8.2)
# Requirement already satisfied: python-dateutil>=2.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in /home/drigols/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (22.2.1)
# Requirement already satisfied: wheel in /home/drigols/anaconda3/lib/python3.9/site-packages (from lightgbm>=2.3.1->pycaret) (0.37.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from matplotlib->pycaret) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from matplotlib->pycaret) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from matplotlib->pycaret) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/drigols/anaconda3/lib/python3.9/site-packages (from matplotlib->pycaret) (0.10.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/drigols/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret) (21.2.0)
# Requirement already satisfied: pytz>=2017.3 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas->pycaret) (2021.3)
# Requirement already satisfied: markupsafe~=2.0.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (2.0.1)
# Requirement already satisfied: missingno>=0.4.2 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (0.5.0)
# Requirement already satisfied: requests>=2.24.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (2.26.0)
# Requirement already satisfied: pydantic>=1.8.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (1.8.2)
# Requirement already satisfied: tqdm>=4.48.2 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (4.62.3)
# Requirement already satisfied: htmlmin>=0.1.12 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (0.1.12)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (0.1.0)
# Requirement already satisfied: jinja2>=2.11.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (2.11.3)
# Requirement already satisfied: phik>=0.11.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (0.12.0)
# Requirement already satisfied: multimethod>=1.4 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (1.6)
# Requirement already satisfied: PyYAML>=5.0.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (6.0)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (0.7.4)
# Requirement already satisfied: networkx>=2.4 in /home/drigols/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (2.6.3)
# Requirement already satisfied: imagehash in /home/drigols/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (4.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->IPython->pycaret) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from plotly>=4.4.1->pycaret) (8.0.1)
# Requirement already satisfied: wcwidth in /home/drigols/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pydantic>=1.8.1->pandas-profiling>=2.8.0->pycaret) (3.10.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/drigols/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/drigols/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (1.26.7)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /home/drigols/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0->pycaret) (1.0.5)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0->pycaret) (7.4.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0->pycaret) (0.9.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0->pycaret) (1.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0->pycaret) (0.7.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/drigols/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0->pycaret) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/drigols/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0->pycaret) (3.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /home/drigols/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0->pycaret) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /home/drigols/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0->pycaret) (1.1.3)
# Requirement already satisfied: notebook>=4.4.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.5.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.8.0)
# Requirement already satisfied: nbconvert in /home/drigols/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.1.0)
# Requirement already satisfied: argon2-cffi in /home/drigols/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/drigols/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.9.4)
# Requirement already satisfied: prometheus-client in /home/drigols/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.11.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.14.6)
# Requirement already satisfied: pycparser in /home/drigols/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.20)
# Requirement already satisfied: PyWavelets in /home/drigols/anaconda3/lib/python3.9/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (1.1.1)
# Requirement already satisfied: Flask in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (1.1.2)
# Requirement already satisfied: sqlalchemy in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (1.4.22)
# Requirement already satisfied: packaging in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (21.0)
# Requirement already satisfied: sqlparse>=0.3.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (0.4.2)
# Requirement already satisfied: gunicorn in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (20.1.0)
# Requirement already satisfied: databricks-cli>=0.8.7 in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (0.16.2)
# Requirement already satisfied: gitpython>=2.1.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (3.1.24)
# Requirement already satisfied: cloudpickle in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (2.0.0)
# Requirement already satisfied: prometheus-flask-exporter in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (0.18.6)
# Requirement already satisfied: querystring-parser in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (1.2.4)
# Requirement already satisfied: protobuf>=3.7.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (3.19.1)
# Requirement already satisfied: alembic<=1.4.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (1.4.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (4.8.1)
# Requirement already satisfied: entrypoints in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (0.3)
# Requirement already satisfied: docker>=4.0.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (5.0.3)
# Requirement already satisfied: click>=7.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from mlflow->pycaret) (8.0.3)
# Requirement already satisfied: Mako in /home/drigols/anaconda3/lib/python3.9/site-packages (from alembic<=1.4.1->mlflow->pycaret) (1.1.6)
# Requirement already satisfied: python-editor>=0.3 in /home/drigols/anaconda3/lib/python3.9/site-packages (from alembic<=1.4.1->mlflow->pycaret) (1.0.4)
# Requirement already satisfied: tabulate>=0.7.7 in /home/drigols/anaconda3/lib/python3.9/site-packages (from databricks-cli>=0.8.7->mlflow->pycaret) (0.8.9)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from docker>=4.0.0->mlflow->pycaret) (1.2.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from gitpython>=2.1.0->mlflow->pycaret) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->pycaret) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/drigols/anaconda3/lib/python3.9/site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/drigols/anaconda3/lib/python3.9/site-packages (from sqlalchemy->mlflow->pycaret) (1.1.1)
# Requirement already satisfied: itsdangerous>=0.24 in /home/drigols/anaconda3/lib/python3.9/site-packages (from Flask->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in /home/drigols/anaconda3/lib/python3.9/site-packages (from Flask->mlflow->pycaret) (2.0.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.4.3)
# Requirement already satisfied: testpath in /home/drigols/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /home/drigols/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/drigols/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.3)
# Requirement already satisfied: bleach in /home/drigols/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.0.0)
# Requirement already satisfied: defusedxml in /home/drigols/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.7.1)
# Requirement already satisfied: nest-asyncio in /home/drigols/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.1)
# Requirement already satisfied: async-generator in /home/drigols/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.10)
# Requirement already satisfied: webencodings in /home/drigols/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/drigols/anaconda3/lib/python3.9/site-packages (from nltk->pycaret) (2021.8.3)
# Requirement already satisfied: numexpr in /home/drigols/anaconda3/lib/python3.9/site-packages (from pyLDAvis->pycaret) (2.7.3)
# Requirement already satisfied: funcy in /home/drigols/anaconda3/lib/python3.9/site-packages (from pyLDAvis->pycaret) (1.17)
# Requirement already satisfied: future in /home/drigols/anaconda3/lib/python3.9/site-packages (from pyLDAvis->pycaret) (0.18.2)
# Requirement already satisfied: statsmodels in /home/drigols/anaconda3/lib/python3.9/site-packages (from pyod->pycaret) (0.12.2)
# Requirement already satisfied: numba>=0.35 in /home/drigols/anaconda3/lib/python3.9/site-packages (from pyod->pycaret) (0.54.1)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /home/drigols/anaconda3/lib/python3.9/site-packages (from numba>=0.35->pyod->pycaret) (0.37.0)
# Requirement already satisfied: patsy>=0.5 in /home/drigols/anaconda3/lib/python3.9/site-packages (from statsmodels->pyod->pycaret) (0.5.2)
# Requirement already satisfied: pynndescent>=0.5 in /home/drigols/anaconda3/lib/python3.9/site-packages (from umap-learn->pycaret) (0.5.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Agora que nós já instalamos o **pycaret** vamos importar os métodos de classificação, visto que nós estamos trabalhando em um problema dessa natureza:

# %%
from pycaret.classification import *

# %% [markdown]
# Agora nós vamos definir um **setup()** para o nosso pycaret, ou seja, quais as configurações nós vamos passar para ele trabalhar:

# %%
s = setup(
  df[
      [
        "satisfaction",
        "evaluation",
        "averageMonthlyHours",
        "yearsAtCompany",
        "turnover"
      ]
    ],
    target = "turnover",
    numeric_features = ["yearsAtCompany"], # If pycaret goes wrong you need to fix it.
    normalize = True,
    normalize_method = "minmax",
    data_split_stratify = True,
    fix_imbalance = True,
)
# Out:
# <style type="text/css">
# #T_9bfa6_row29_col1, #T_9bfa6_row44_col1, #T_9bfa6_row58_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9bfa6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bfa6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bfa6_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_9bfa6_row0_col1" class="data row0 col1" >315</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9bfa6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9bfa6_row1_col1" class="data row1 col1" >turnover</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9bfa6_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_9bfa6_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9bfa6_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_9bfa6_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9bfa6_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_9bfa6_row4_col1" class="data row4 col1" >(14998, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9bfa6_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_9bfa6_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9bfa6_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_9bfa6_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9bfa6_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_9bfa6_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9bfa6_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_9bfa6_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9bfa6_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_9bfa6_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9bfa6_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_9bfa6_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9bfa6_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_9bfa6_row11_col1" class="data row11 col1" >(10498, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9bfa6_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_9bfa6_row12_col1" class="data row12 col1" >(4500, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9bfa6_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_9bfa6_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9bfa6_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_9bfa6_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9bfa6_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_9bfa6_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9bfa6_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_9bfa6_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9bfa6_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_9bfa6_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9bfa6_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_9bfa6_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9bfa6_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_9bfa6_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9bfa6_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_9bfa6_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9bfa6_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_9bfa6_row21_col1" class="data row21 col1" >ba13</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9bfa6_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_9bfa6_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_9bfa6_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_9bfa6_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_9bfa6_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_9bfa6_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_9bfa6_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_9bfa6_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_9bfa6_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_9bfa6_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_9bfa6_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_9bfa6_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_9bfa6_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_9bfa6_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_9bfa6_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_9bfa6_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9bfa6_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_9bfa6_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_9bfa6_row30_col1" class="data row

# %% [markdown]
# ## 24 - Comparando diferentes modelos com Pycaret
# Uma das maiores vantagens do **Pycaret** é ver o resultado da **accuracy** para o nosso conjunto de dados em vários Algoritmos de *Machine Learning* diferentes.
#
# **NOTE:**
# Porém, como nós já sabemos que os nossos dados estão desbalanceados (principalmente para a variável target = turnover) nós vamos especificar para o **Pycaret** focar na **Curva AUC** em vários Algoritmos de Machine Learning para nosso conjunto de dados:

# %%
best = compare_models(fold = 5, sort = 'AUC',)
# Out:
# <style type="text/css">
# #T_e46af_ th {
#   text-align: left;
# }
# #T_e46af_row0_col0, #T_e46af_row0_col1, #T_e46af_row0_col3, #T_e46af_row0_col4, #T_e46af_row0_col5, #T_e46af_row0_col6, #T_e46af_row0_col7, #T_e46af_row1_col0, #T_e46af_row1_col1, #T_e46af_row1_col2, #T_e46af_row1_col3, #T_e46af_row1_col4, #T_e46af_row1_col5, #T_e46af_row1_col6, #T_e46af_row1_col7, #T_e46af_row2_col0, #T_e46af_row2_col2, #T_e46af_row2_col3, #T_e46af_row3_col0, #T_e46af_row3_col1, #T_e46af_row3_col2, #T_e46af_row3_col3, #T_e46af_row3_col4, #T_e46af_row3_col5, #T_e46af_row3_col6, #T_e46af_row3_col7, #T_e46af_row4_col0, #T_e46af_row4_col1, #T_e46af_row4_col2, #T_e46af_row4_col4, #T_e46af_row4_col5, #T_e46af_row4_col6, #T_e46af_row4_col7, #T_e46af_row5_col0, #T_e46af_row5_col1, #T_e46af_row5_col2, #T_e46af_row5_col3, #T_e46af_row5_col4, #T_e46af_row5_col5, #T_e46af_row5_col6, #T_e46af_row5_col7, #T_e46af_row6_col0, #T_e46af_row6_col1, #T_e46af_row6_col2, #T_e46af_row6_col3, #T_e46af_row6_col4, #T_e46af_row6_col5, #T_e46af_row6_col6, #T_e46af_row6_col7, #T_e46af_row7_col0, #T_e46af_row7_col1, #T_e46af_row7_col2, #T_e46af_row7_col3, #T_e46af_row7_col4, #T_e46af_row7_col5, #T_e46af_row7_col6, #T_e46af_row7_col7, #T_e46af_row8_col0, #T_e46af_row8_col1, #T_e46af_row8_col2, #T_e46af_row8_col3, #T_e46af_row8_col4, #T_e46af_row8_col5, #T_e46af_row8_col6, #T_e46af_row8_col7, #T_e46af_row9_col0, #T_e46af_row9_col1, #T_e46af_row9_col2, #T_e46af_row9_col3, #T_e46af_row9_col4, #T_e46af_row9_col5, #T_e46af_row9_col6, #T_e46af_row9_col7, #T_e46af_row10_col0, #T_e46af_row10_col1, #T_e46af_row10_col2, #T_e46af_row10_col3, #T_e46af_row10_col4, #T_e46af_row10_col5, #T_e46af_row10_col6, #T_e46af_row10_col7, #T_e46af_row11_col0, #T_e46af_row11_col1, #T_e46af_row11_col2, #T_e46af_row11_col3, #T_e46af_row11_col4, #T_e46af_row11_col5, #T_e46af_row11_col6, #T_e46af_row11_col7, #T_e46af_row12_col0, #T_e46af_row12_col1, #T_e46af_row12_col2, #T_e46af_row12_col3, #T_e46af_row12_col4, #T_e46af_row12_col5, #T_e46af_row12_col6, #T_e46af_row12_col7, #T_e46af_row13_col0, #T_e46af_row13_col1, #T_e46af_row13_col2, #T_e46af_row13_col3, #T_e46af_row13_col4, #T_e46af_row13_col5, #T_e46af_row13_col6, #T_e46af_row13_col7 {
#   text-align: left;
# }
# #T_e46af_row0_col2, #T_e46af_row2_col1, #T_e46af_row2_col4, #T_e46af_row2_col5, #T_e46af_row2_col6, #T_e46af_row2_col7, #T_e46af_row4_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e46af_row0_col8, #T_e46af_row1_col8, #T_e46af_row2_col8, #T_e46af_row3_col8, #T_e46af_row4_col8, #T_e46af_row5_col8, #T_e46af_row6_col8, #T_e46af_row7_col8, #T_e46af_row8_col8, #T_e46af_row9_col8, #T_e46af_row10_col8, #T_e46af_row11_col8, #T_e46af_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e46af_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e46af_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e46af_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_e46af_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_e46af_row0_col1" class="data row0 col1" >0.8015</td>
#       <td id="T_e46af_row0_col2" class="data row0 col2" >0.7691</td>
#       <td id="T_e46af_row0_col3" class="data row0 col3" >0.6523</td>
#       <td id="T_e46af_row0_col4" class="data row0 col4" >0.5731</td>
#       <td id="T_e46af_row0_col5" class="data row0 col5" >0.6100</td>
#       <td id="T_e46af_row0_col6" class="data row0 col6" >0.4777</td>
#       <td id="T_e46af_row0_col7" class="data row0 col7" >0.4795</td>
#       <td id="T_e46af_row0_col8" class="data row0 col8" >0.5560</td>
#     </tr>
#     <tr>
#       <th id="T_e46af_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_e46af_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_e46af_row1_col1" class="data row1 col1" >0.7789</td>
#       <td id="T_e46af_row1_col2" class="data row1 col2" >0.7663</td>
#       <td id="T_e46af_row1_col3" class="data row1 col3" >0.6767</td>
#       <td id="T_e46af_row1_col4" class="data row1 col4" >0.5280</td>
#       <td id="T_e46af_row1_col5" class="data row1 col5" >0.5930</td>
#       <td id="T_e46af_row1_col6" class="data row1 col6" >0.4444</td>
#       <td id="T_e46af_row1_col7" class="data row1 col7" >0.4510</td>
#       <td id="T_e46af_row1_col8" class="data row1 col8" >0.2760</td>
#     </tr>
#     <tr>
#       <th id="T_e46af_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_e46af_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e46af_row2_col1" class="data row2 col1" >0.8245</td>
#       <td id="T_e46af_row2_col2" class="data row2 col2" >0.7662</td>
#       <td id="T_e46af_row2_col3" class="data row2 col3" >0.6079</td>
#       <td id="T_e46af_row2_col4" class="data row2 col4" >0.6380</td>
#       <td id="T_e46af_row2_col5" class="data row2 col5" >0.6224</td>
#       <td id="T_e46af_row2_col6" class="data row2 col6" >0.5082</td>
#       <td id="T_e46af_row2_col7" class="data row2 col7" >0.5086</td>
#       <td id="T_e46af_row2_col8" class="data row2 col8" >0.3300</td>
#     </tr>
#     <tr>
#       <th id="T_e46af_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_e46af_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_e46af_row3_col1" class="data row3 col1" >0.7907</td>
#       <td id="T_e46af_row3_col2" class="data row3 col2" >0.7444</td>
#       <td id="T_e46af_row3_col3" class="data row3 col3" >0.5106</td>
#       <td id="T_e46af_row3_col4" class="data row3 col4" >0.5668</td>
#       <td id="T_e46af_row3_col5" class="data row3 col5" >0.5368</td>
#       <td id="T_e46af_row3_col6" class="data row3 col6" >0.4023</td>
#       <td id="T_e46af_row3_col7" class="data row3 col7" >0.4034</td>
#       <td id="T_e46af_row3_col8" class="data row3 col8" >0.9580</td>
#     </tr>
#     <tr>
#       <th id="T_e46af_level0_row4" class="row_heading level0 row4" >qda</th>
#       <td id="T_e46af_row4_col0" class="data row4 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_e46af_row4_col1" class="data row4 col1" >0.7066</td>
#       <td id="T_e46af_row4_col2" class="data row4 col2" >0.7256</td>
#       <td id="T_e46af_row4_col3" class="data row4 col3" >0.7179</td>
#       <td id="T_e46af_row4_col4" class="data row4 col4" >0.4303</td>
#       <td id="T_e46af_row4_col5" class="data row4 col5" >0.5380</td>
#       <td id="T_e46af_row4_col6" class="data row4 col6" >0.3422</td>
#       <td id="T_e46af_row4_col7" class="data row4 col7" >0.3665</td>
#       <td id="T_e46af_row4_col8" class="data row4 col8" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_e46af_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_e46af_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_e46af_row5_col1" class="data row5 col1" >0.7049</td>
#       <td id="T_e46af_row5_col2" class="data row5 col2" >0.7198</td>
#       <td id="T_e46af_row5_col3" class="data row5 col3" >0.6419</td>
#       <td id="T_e46af_row5_col4" class="data row5 col4" >0.4214</td>
#       <td id="T_e46af_row5_col5" class="data row5 col5" >0.5088</td>
#       <td id="T_e46af_row5_col6" class="data row5 col6" >0.3106</td>
#       <td id="T_e46af_row5_col7" class="data row5 col7" >0.3247</td>
#       <td id="T_e46af_row5_col8" class="data row5 col8" >0.1300</td>
#     </tr>
#     <tr>
#       <th id="T_e46af_level0_row6" class="row_heading level0 row6" >et</th>
#       <td id="T_e46af_row6_col0" class="data row6 c

# %% [markdown]
# **NOTE:**
# Veja que para cada Algoritmo de Machine Learning o **Pycaret** retornou várias métricas, como **accuracy** e **Curva AUC**.
#
# **NOTE:**
# Outra observação é que o **Pycaret** destacou todas às *melhor métrica* em amarelo. E a **Curva AUC (métrica)** que é o que nós interessa foi o Algoritmo GBC.
#
# Agora que nós já sabemos qual foi o melhor Algoritmo (seguindo a métrica de preferência que nós definimos - AUC), vamos exibir ele só para ver o que ele nós retorna:

# %%
best
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=315, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %% [markdown]
# ## 25 - Treinando nosso modelo com o Algoritmo GBC & Pycaret
# Ótimo, agora que o **Pycaret** já nós deu de mão beijada o Algoritmo com melhor **Curva AUC** vamos treinar nosso modelo com esse Algoritmo:

# %%
gbc = create_model('gbc', fold = 5)
# Out:
# <style type="text/css">
# #T_64ade_row5_col0, #T_64ade_row5_col1, #T_64ade_row5_col2, #T_64ade_row5_col3, #T_64ade_row5_col4, #T_64ade_row5_col5, #T_64ade_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_64ade_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64ade_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64ade_row0_col0" class="data row0 col0" >0.7981</td>
#       <td id="T_64ade_row0_col1" class="data row0 col1" >0.7634</td>
#       <td id="T_64ade_row0_col2" class="data row0 col2" >0.6480</td>
#       <td id="T_64ade_row0_col3" class="data row0 col3" >0.5664</td>
#       <td id="T_64ade_row0_col4" class="data row0 col4" >0.6045</td>
#       <td id="T_64ade_row0_col5" class="data row0 col5" >0.4697</td>
#       <td id="T_64ade_row0_col6" class="data row0 col6" >0.4717</td>
#     </tr>
#     <tr>
#       <th id="T_64ade_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64ade_row1_col0" class="data row1 col0" >0.7957</td>
#       <td id="T_64ade_row1_col1" class="data row1 col1" >0.7579</td>
#       <td id="T_64ade_row1_col2" class="data row1 col2" >0.6220</td>
#       <td id="T_64ade_row1_col3" class="data row1 col3" >0.5644</td>
#       <td id="T_64ade_row1_col4" class="data row1 col4" >0.5918</td>
#       <td id="T_64ade_row1_col5" class="data row1 col5" >0.4560</td>
#       <td id="T_64ade_row1_col6" class="data row1 col6" >0.4570</td>
#     </tr>
#     <tr>
#       <th id="T_64ade_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64ade_row2_col0" class="data row2 col0" >0.8062</td>
#       <td id="T_64ade_row2_col1" class="data row2 col1" >0.7953</td>
#       <td id="T_64ade_row2_col2" class="data row2 col2" >0.6720</td>
#       <td id="T_64ade_row2_col3" class="data row2 col3" >0.5803</td>
#       <td id="T_64ade_row2_col4" class="data row2 col4" >0.6228</td>
#       <td id="T_64ade_row2_col5" class="data row2 col5" >0.4933</td>
#       <td id="T_64ade_row2_col6" class="data row2 col6" >0.4957</td>
#     </tr>
#     <tr>
#       <th id="T_64ade_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64ade_row3_col0" class="data row3 col0" >0.8137</td>
#       <td id="T_64ade_row3_col1" class="data row3 col1" >0.7709</td>
#       <td id="T_64ade_row3_col2" class="data row3 col2" >0.6613</td>
#       <td id="T_64ade_row3_col3" class="data row3 col3" >0.5978</td>
#       <td id="T_64ade_row3_col4" class="data row3 col4" >0.6280</td>
#       <td id="T_64ade_row3_col5" class="data row3 col5" >0.5041</td>
#       <td id="T_64ade_row3_col6" class="data row3 col6" >0.5053</td>
#     </tr>
#     <tr>
#       <th id="T_64ade_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64ade_row4_col0" class="data row4 col0" >0.7937</td>
#       <td id="T_64ade_row4_col1" class="data row4 col1" >0.7582</td>
#       <td id="T_64ade_row4_col2" class="data row4 col2" >0.6580</td>
#       <td id="T_64ade_row4_col3" class="data row4 col3" >0.5567</td>
#       <td id="T_64ade_row4_col4" class="data row4 col4" >0.6031</td>
#       <td id="T_64ade_row4_col5" class="data row4 col5" >0.4651</td>
#       <td id="T_64ade_row4_col6" class="data row4 col6" >0.4680</td>
#     </tr>
#     <tr>
#       <th id="T_64ade_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_64ade_row5_col0" class="data row5 col0" >0.8015</td>
#       <td id="T_64ade_row5_col1" class="data row5 col1" >0.7691</td>
#       <td id="T_64ade_row5_col2" class="data row5 col2" >0.6523</td>
#       <td id="T_64ade_row5_col3" class="data row5 col3" >0.5731</td>
#       <td id="T_64ade_row5_col4" class="data row5 col4" >0.6100</td>
#       <td id="T_64ade_row5_col5" class="data row5 col5" >0.4777</td>
#       <td id="T_64ade_row5_col6" class="data row5 col6" >0.4795</td>
#     </tr>
#     <tr>
#       <th id="T_64ade_level0_row6" class="row_heading level0 row6" >SD</th>
#       <td id="T_64ade_row6_col0" class="data row6 col0" >0.0074</td>
#       <td id="T_64ade_row6_col1" class="data row6 col1" >0.0139</td>
#       <td id="T_64ade_row6_col2" class="data row6 col2" >0.0170</td>
#       <td id="T_64ade_row6_col3" class="data row6 col3" >0.0145</td>
#       <td id="T_64ade_row6_col4" class="data row6 col4" >0.0134</td>
#       <td id="T_64ade_row6_col5" class="data row6 col5" >0.0181</td>
#       <td id="T_64ade_row6_col6" class="data row6 col6" >0.0181</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **NOTE:**
# Veja que para cada **Fold** o **Pycaret** nós mostra o resultado de cada **métrica**.

# %% [markdown]
# ## 26 - Realizando o tunning do nosso modelo com Pycaret
# Agora nós vamos aplicar o conceito de **Hyperparameter Tuning** com **Pycaret**

# %%
tuned_gbc = tune_model(
  gbc,
  fold = 5,
  custom_grid = {
    "learning_rate": [0.1, 0.2, 0.5],
    "n_estimators": [100, 500, 1000],
    "min_samples_split": [1, 2, 5, 10],
    "max_depth": [1, 3, 9]
  },
  optimize = 'AUC'
)
# Out:
# <style type="text/css">
# #T_089b1_row5_col0, #T_089b1_row5_col1, #T_089b1_row5_col2, #T_089b1_row5_col3, #T_089b1_row5_col4, #T_089b1_row5_col5, #T_089b1_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_089b1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_089b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_089b1_row0_col0" class="data row0 col0" >0.8219</td>
#       <td id="T_089b1_row0_col1" class="data row0 col1" >0.7661</td>
#       <td id="T_089b1_row0_col2" class="data row0 col2" >0.5840</td>
#       <td id="T_089b1_row0_col3" class="data row0 col3" >0.6376</td>
#       <td id="T_089b1_row0_col4" class="data row0 col4" >0.6096</td>
#       <td id="T_089b1_row0_col5" class="data row0 col5" >0.4945</td>
#       <td id="T_089b1_row0_col6" class="data row0 col6" >0.4953</td>
#     </tr>
#     <tr>
#       <th id="T_089b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_089b1_row1_col0" class="data row1 col0" >0.8171</td>
#       <td id="T_089b1_row1_col1" class="data row1 col1" >0.7523</td>
#       <td id="T_089b1_row1_col2" class="data row1 col2" >0.5880</td>
#       <td id="T_089b1_row1_col3" class="data row1 col3" >0.6229</td>
#       <td id="T_089b1_row1_col4" class="data row1 col4" >0.6049</td>
#       <td id="T_089b1_row1_col5" class="data row1 col5" >0.4861</td>
#       <td id="T_089b1_row1_col6" class="data row1 col6" >0.4864</td>
#     </tr>
#     <tr>
#       <th id="T_089b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_089b1_row2_col0" class="data row2 col0" >0.8290</td>
#       <td id="T_089b1_row2_col1" class="data row2 col1" >0.7909</td>
#       <td id="T_089b1_row2_col2" class="data row2 col2" >0.6280</td>
#       <td id="T_089b1_row2_col3" class="data row2 col3" >0.6448</td>
#       <td id="T_089b1_row2_col4" class="data row2 col4" >0.6363</td>
#       <td id="T_089b1_row2_col5" class="data row2 col5" >0.5246</td>
#       <td id="T_089b1_row2_col6" class="data row2 col6" >0.5246</td>
#     </tr>
#     <tr>
#       <th id="T_089b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_089b1_row3_col0" class="data row3 col0" >0.8280</td>
#       <td id="T_089b1_row3_col1" class="data row3 col1" >0.7626</td>
#       <td id="T_089b1_row3_col2" class="data row3 col2" >0.6152</td>
#       <td id="T_089b1_row3_col3" class="data row3 col3" >0.6450</td>
#       <td id="T_089b1_row3_col4" class="data row3 col4" >0.6297</td>
#       <td id="T_089b1_row3_col5" class="data row3 col5" >0.5178</td>
#       <td id="T_089b1_row3_col6" class="data row3 col6" >0.5181</td>
#     </tr>
#     <tr>
#       <th id="T_089b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_089b1_row4_col0" class="data row4 col0" >0.8152</td>
#       <td id="T_089b1_row4_col1" class="data row4 col1" >0.7569</td>
#       <td id="T_089b1_row4_col2" class="data row4 col2" >0.5940</td>
#       <td id="T_089b1_row4_col3" class="data row4 col3" >0.6162</td>
#       <td id="T_089b1_row4_col4" class="data row4 col4" >0.6049</td>
#       <td id="T_089b1_row4_col5" class="data row4 col5" >0.4843</td>
#       <td id="T_089b1_row4_col6" class="data row4 col6" >0.4844</td>
#     </tr>
#     <tr>
#       <th id="T_089b1_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_089b1_row5_col0" class="data row5 col0" >0.8223</td>
#       <td id="T_089b1_row5_col1" class="data row5 col1" >0.7658</td>
#       <td id="T_089b1_row5_col2" class="data row5 col2" >0.6018</td>
#       <td id="T_089b1_row5_col3" class="data row5 col3" >0.6333</td>
#       <td id="T_089b1_row5_col4" class="data row5 col4" >0.6171</td>
#       <td id="T_089b1_row5_col5" class="data row5 col5" >0.5015</td>
#       <td id="T_089b1_row5_col6" class="data row5 col6" >0.5018</td>
#     </tr>
#     <tr>
#       <th id="T_089b1_level0_row6" class="row_heading level0 row6" >SD</th>
#       <td id="T_089b1_row6_col0" class="data row6 col0" >0.0056</td>
#       <td id="T_089b1_row6_col1" class="data row6 col1" >0.0134</td>
#       <td id="T_089b1_row6_col2" class="data row6 col2" >0.0169</td>
#       <td id="T_089b1_row6_col3" class="data row6 col3" >0.0117</td>
#       <td id="T_089b1_row6_col4" class="data row6 col4" >0.0133</td>
#       <td id="T_089b1_row6_col5" class="data row6 col5" >0.0166</td>
#       <td id="T_089b1_row6_col6" class="data row6 col6" >0.0165</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **NOTE:**
#  - Primeiro, não se preocupe se demorar muito, pois, o Algoritmo está testando todos os parâmetros passados;
#  - Segundo, veja que nós tivemos quase os mesmos resultados de apenas executar o Algoritmo GBC:
#    - Isso, porque o Algoritmo GBC já escolheu bons parâmetros na hora do treino, porém, não é sempre assim para todos os Algoritmos e também depende do conjunto de dados.

# %% [markdown]
# ## 27 - Finalizando nosso modelo com Pycaret
# Ok, chegou a hora! Até então nós estavamos nas partes de análise, treinamento de modelos e escolha do melhor Algoritmo de Machine Learning para o nosso problema e conjunto de dados.
#
# Agora que nós já sabemos qual o melhor Algoritmo de Machine Learning para o nosso conjunto de dados vamos treinar esse Algoritmo, porém, utilizando:
#
# > **TODO NOSSO CONJUNTO DE DADOS (OU SEJA, 100% DOS DADOS)**.
#
# **NOTE:**
# Isso mesmo, em um ambiente de produção nosso Algoritmo trabalha com todo nosso conjunto de dados. Os dados de testes já diz tudo - **Estamos apenas testando fora do ambiente de produção**.
#
# O **Pycaret** tem o método **finalize_model()** que pega todo o nosso conjunto de dados e parâmetros e *finaliza* nosso modelo:

# %%
final_model = finalize_model(tuned_gbc)

# %% [markdown]
# ## 28 - Salvando nosso modelo com Pycaret
# Com nosso modelo finalizado vamos utilizar o método **save_model()** do **Pycaret** para salvar nosso modelo:

# %%
save_model(final_model, 'my_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['yearsAtCompany'],
#                                        target='turnover', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=...
#                                              learning_rate=0.1, loss='deviance',
#                                              max_depth=3, max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=5,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=500,
#                                              n_iter_no_change=None,
#                                              presort='deprecated',
#                                              random_state=315, subsample=1.0,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False)]],
#           verbose=False),
#  'my_model.pkl')

# %% [markdown]
# **NOTE**
# Esse modelo está salvo em um arquivo chamado **my_model.pkl** (que foi o nome que nós especificamos na hora de salvar o modelo) no mesmo diretório do nosso *Jupyter Notebook*.

# %% [markdown]
# ## 29 - Transferindo nosso modelo para o Data Lake
# Ótimo, agora que nós já finalizamos todas nossas análises, treinamos nosso modelo, salvamos nosso modelo, chegou a hora de transferir o mesmo para o nosso **Data Lake**.

# %%
client.fput_object(
  "curated",
  "my_model.pkl",
  "my_model.pkl"
)

# %% [markdown]
# **NOTE:**
# Veja que nós estamos enviando nosso modelo para a **zona (bucket) curated**.

# %% [markdown]
# ## 30 - Exportando o conjunto de dados para o disco
# Ok, agora se eu precisar desse conjunto de dados (DataFrame) já organizado, por exemplo, para exibir em um **App** de visualização de dados?
#
# Simples, primeiro vamos criar uma cópia dele no nosso *disco local* com o método **to_csv()** do Pandas:

# %%
df.to_csv("dataset.csv", index=False)

# %% [markdown]
# Pronto, agora foi criado no mesmo diretório do nosso *Jupyter Notebook* um arquivo chamado **dataset.csv**.
#
# > E se eu precisar desse arquivo na minha **zona (Bucket) curated**?
#
# Simples, vamos enviar ele para lá agora:

# %%
client.fput_object(
  "curated",
  "dataset.csv",
  "dataset.csv"
)
